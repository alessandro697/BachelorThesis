# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.transforms as mtransforms

my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_0.75__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 

R1 = np.sqrt(3)/4
R2 = 0.75
c = 1
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('Fig 11 (b)')
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], 0.75*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/4)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()



#xcm e r sullo stesso grafico
fig, (ax1, ax2) = plt.subplots(2, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(46, 0.82, '$R_2$',color='orangered')
ax1.text(46, 0.34, '$R_1$', color='forestgreen')
ax1.set(ylabel='$x_2-x_1 \quad [a]$', ylim = [0.31,1])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.31,1])
ax1R.set(xlim=[0,100])


ax2.plot(data[:,0], xcm , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax2.set(ylabel='$x_{cm} \quad [a]$', ylim = [0,48])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.set(ylim = [0,48])
ax2R.set(xlim=[0,100])

ax2.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')

trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0.0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.subplots_adjust(wspace=0, hspace=0)
plt.xlim([0,100])
plt.savefig("11_b_R_Xcm.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# La barriera di potenziale è :  0.026367187500000014

# %%
#r e forzante sullo stesso grafico

f = -2*np.pi*np.sin(np.pi*r)*np.cos(np.pi*xcm*2)



fig, (ax1, ax2) = plt.subplots(2, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(18, 0.82, '$R_2$',color='orangered')
ax1.text(18, 0.38, '$R_1$', color='forestgreen')
ax1.set(ylabel='$r \quad [a]$', ylim = [0.35,0.92])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.35,0.92])
ax1T.set(xlim=[0,50])
ax1R.set(xlim=[0,50])


ax2.plot(data[:,0], f , label='$2\sin(\pir) \cos(2\pi x_{cm})$', color ='darkblue',linewidth=1)
ax2.set(ylabel='$F_{dri}^{eff} \quad [V_0/a]$',ylim = [-7,8])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[0,50])
ax2R.set(ylim = [-7,8])


ax2.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')


trans = mtransforms.ScaledTranslation(0, -5/72, fig.dpi_scale_trans)
ax1.text(0.92, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.92, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.xlim([0,50])
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_b_R_Forzante.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
from scipy.fft import fft, fftfreq
start = 4500
end = 5000
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)
R = fft(r[start:end])
freqr = fftfreq(end-start)*10
plt.plot(freqr, np.abs(R),label='frequency')
plt.xlim([0.2,0.6])
plt.ylim([0,300])
plt.plot([vcm,vcm],[0,500],label='Vcm',linestyle='dashed')
plt.legend()

plt.show()

y = f[start:end]
Y = fft(y)
freqr = fftfreq(len(y))*10
plt.plot(freqr, np.abs(Y),label='frequency')
plt.plot([vcm,vcm],[0,5000],label='Vcm',linestyle='dashed')
plt.xlim([0.2,0.6])

plt.legend()
plt.show()
# Out:
# 0.39482687403685474

# %%
import scipy.integrate

start = 4500
end = 5000
#calcolo energia immessa
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))
P = y*(-data[start:end,4]+data[start:end,5])
energy = scipy.integrate.trapz(P, data[start:end,0])
print(energy)
spaces = np.arange(100)
e1 = np.zeros(100)

for i in spaces:
    term = int(start + (i+1)*(end-start)/len(spaces))
    e1[i] = scipy.integrate.trapz(P[:int((i+1)*(end-start)/len(spaces))], data[start:term,0])
    
term = start + (spaces+1)*(end-start)/len(spaces)
plt.xlabel('T')
plt.ylabel('W')
plt.title('Exact work')
plt.plot(term,e1,linewidth=1)
plt.grid()
plt.show()
# Out:
# 67.87658625333705

# %%
#ora con approssimazione cos(wt)
y2 = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start,2]+data[start,3]+2*vcm*data[0:end-start,0]))
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)



P2 = y2*(-data[start:end,4]+data[start:end,5])
energy2 = scipy.integrate.trapz(P2, data[start:end,0])
print(energy2)
e2 = np.zeros(100)

for i in spaces:
    term = int(start + (i+1)*(end-start)/len(spaces))
    e2[i] = scipy.integrate.trapz(P2[:int((i+1)*(end-start)/len(spaces))], data[start:term,0])
    
term = start + (spaces+1)*(end-start)/len(spaces)
plt.xlabel('T')
plt.ylabel('W')
plt.title('Approximate work')
plt.plot(term,e2,linewidth=1)
plt.grid()
plt.show()


plt.xlabel('T')
plt.ylabel('(W2-W1)/(W2+W1)')
plt.title('Normalized Difference')
plt.plot(term,(-e2+e1)/(e2+e1),linewidth=1)
plt.grid()
plt.show()
# Out:
# 0.39482687403685474
# 67.4475705318676

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)

ax1.plot(term/10,e1, color ='darkblue',linewidth=1)

ax1.set(ylabel=r'$W_{ex} \quad [V_0]$', ylim = [1,70])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylabel='(a)',ylim = [1,70])
ax1T.set(xlim=[450,500])
ax1R.set(xlim=[450,500])


ax2.plot(term/10,e2, color ='darkblue',linewidth=1)
ax2.set(ylabel=r'$W_{app} \quad [V_0]$', ylim = [1,70])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[450,500])
ax2R.set(xlim=[450,500])
ax2R.set(ylabel='(b)',ylim = [1,70])


ax3.plot(term/10,(e1-e2)/(e2+e1), color ='darkblue',linewidth=1)
ax3.set(ylabel=r'$ \Delta$')

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3T.set(xlim=[450,500])
ax3R.set(xlim=[450,500])
ax3R.set(ylabel='(c)')

ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')



plt.xlim([450,500])
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_b_Work.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, (ax1,  ax3) = plt.subplots(2, sharex=True)

ax1.plot(term/10,e1, color ='darkblue',linewidth=1)

ax1.set(ylabel=r'$Work \quad [V_0]$', ylim = [1,70])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [1,70])
ax1T.set(xlim=[450,500])
ax1R.set(xlim=[450,500])


ax1.plot(term/10,e2, color ='orangered', linestyle = 'dashed',linewidth=1)
ax1.text(486,42,r'$W_{app}$',color='orangered')
ax1.text(480,47,r'$W_{ex}$',color='darkblue')



ax3.plot(term/10,(e1-e2)/(e1), color ='darkblue',linewidth=1)
ax3.set(ylabel=r'$ \Delta$', ylim = [-0.04,0.08])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3T.set(xlim=[450,500])
ax3R.set(xlim=[450,500])
ax3R.set(ylim = [-0.04,0.08])

ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')


trans = mtransforms.ScaledTranslation(0, 5/72, fig.dpi_scale_trans)
ax1.text(0.94, 0.12, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0.94, 0.12, '(b)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))


plt.xlim([450,500])
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_b_Work_b.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
#r e forzante sullo stesso grafico
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_0.75__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)
r = data[:,3]-data[:,2]
start = 0
end = 500
#calcolo energia immessa
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))
P = y*(-data[start:end,4]+data[start:end,5])
energy = scipy.integrate.trapz(P, data[start:end,0])
print(energy)
spaces = np.arange(10000)
e1 = np.zeros(10000)

for i in spaces:
    term = int(start + (i+1)*(end-start)/len(spaces))
    e1[i] = scipy.integrate.trapz(P[:int((i+1)*(end-start)/len(spaces))], data[start:term,0])
    
term = start + (spaces+1)*(end-start)/len(spaces)

f = -2*np.pi*np.sin(np.pi*r)*np.cos(np.pi*xcm*2)


fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(18, 0.82, '$R_2$',color='orangered')
ax1.text(18, 0.38, '$R_1$', color='forestgreen')
ax1.set(ylabel='$r \quad [a]$', ylim = [0.35,0.95])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.35,0.95])
ax1T.set(xlim=[0,25])
ax1R.set(xlim=[0,25])


ax2.plot(data[:,0], f , label='$2\sin(\pir) \cos(2\pi x_{cm})$', color ='darkblue',linewidth=1)
ax2.set(ylabel='$F_{dri}^{eff} \quad [V_0/a]$',ylim = [-7,8])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[0,25])
ax2R.set(ylim = [-7,8])

ax3.plot(term/10,e1, color ='darkblue',linewidth=1)
ax3.set(ylabel=r'$Work \quad [V_0]$', ylim = [0,39])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set(ylim = [0,39])
ax3T.set(xlim=[0,25])
ax3R.set(xlim=[0,25])

ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')


trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0.905, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.91, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0.905, 1.0, '(c)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))



plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_b_R_Forzante_2.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 66.45916429743231

# %%
#cambio spaziatura iniziale molecola

'R=R1'
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_0.4330127__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R = R1')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], 0.75*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/4)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)


'R=0.2'
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_0.2__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R = 0.2')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.grid()
plt.xlim([0,100])
plt.plot(data[:,0], (np.sqrt(3)/4)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)

'R=0.35'
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_0.35__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R = 0.35')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.grid()
plt.plot(data[:,0], 0.75*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/4)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.xlim([0,100])
plt.show()
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)


'R=0.4'
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_0.4__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R = 0.4')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], 0.75*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/4)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)

'R=1'
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_5.0__R_1.0__R2_0.4330127__R3_0.75__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R = 1')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], 0.75*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/4)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print(vcm)
# Out:
# 0.3937151261475599
# 0.3930276162386578
# 0.3939589477771402
# 0.3937694595213643
# 0.39219104424449047
