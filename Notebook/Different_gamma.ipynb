# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.fft import fft, fftfreq

# %%
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.1__R2_0.14433756__R3_0.25__c_1000.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 1000



plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('g1 = g2 = 10')
#particella 2 - particella 1
r = data[:,3]-data[:,2]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.grid()
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], R1*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
#plt.xlim([0,50])
plt.show()

start = int(len(r)/5)
end = len(r)
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.6911252602153929
# La frequenza armonica in un intorno di R2 è :  1.258230302612176
# La barriera di potenziale è :  0.03616898148148148

# %%
my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_9.0__U0_1.0__F_7.5__R_0.1__R2_0.14433756__R3_0.25__c_1000.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 1000

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
#plt.title('g1 = 10, g2 = 5')
#particella 2 - particella 1
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
#plt.grid()
plt.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
plt.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
#plt.legend()

plt.text(18, 0.235, '$R_2$',color='orangered')
plt.text(18, 0.15, '$R_1$', color='forestgreen')
plt.xlim([0,20])
#plt.savefig("Prova1.pdf", dpi=300, bbox_inches='tight')
plt.show()

start = int(len(r)/5)
end = len(r)
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.7291932486762248
# La frequenza armonica in un intorno di R2 è :  1.258230302612176
# La barriera di potenziale è :  0.03616898148148148

# %%
my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_5.0__U0_1.0__F_7.5__R_0.0__R2_0.14433756__R3_0.25__c_10000.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 10000

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
#plt.title('g1 = 10, g2 = 5')
#particella 2 - particella 1
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
#plt.grid()
plt.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
plt.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
#plt.legend()

plt.text(18, 0.235, '$R_2$',color='orangered')
plt.text(18, 0.15, '$R_1$', color='forestgreen')
plt.xlim([0,20])
#plt.savefig("Prova1.pdf", dpi=300, bbox_inches='tight')
plt.show()

start = int(len(r)/5)
end = len(r)
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.9417718918501929
# La frequenza armonica in un intorno di R2 è :  3.9788735772973842
# La barriera di potenziale è :  0.36168981481481477

# %%
my_file = pd.read_csv("output___n_2__gam1_2.0__gam2_1.0__U0_1.0__F_7.5__R_0.1__R2_0.14433756__R3_0.25__c_1000.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 1000



plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('g1 = 2, g2 = 1')
#particella 2 - particella 1
r = data[:,3]-data[:,2]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.grid()
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], R1*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
#plt.xlim([20,25])
plt.show()

start = int(len(r)/5)
end = len(r)
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  4.998681793296955
# La frequenza armonica in un intorno di R2 è :  1.258230302612176
# La barriera di potenziale è :  0.03616898148148148

# %%
my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_5.0__U0_1.0__F_7.5__R_0.0__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/4
R2 = 0.75
c = 10

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
#plt.title('g1 = 10, g2 = 5')
#particella 2 - particella 1
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
#plt.grid()
plt.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
plt.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
#plt.legend()

plt.text(18, 0.235*3, '$R_2$',color='orangered')
plt.text(18, 0.15*3, '$R_1$', color='forestgreen')
plt.xlim([0,20])
#plt.savefig("Prova1.pdf", dpi=300, bbox_inches='tight')
plt.show()

start = int(len(r)/5)
end = len(r)
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.9482399527776274
# La frequenza armonica in un intorno di R2 è :  1.1324072723509584
# La barriera di potenziale è :  0.2636718750000001

# %%
my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_9.0__U0_1.0__F_7.5__R_0.0__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/4
R2 = 0.75
c = 10

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
plt.title('g1 = 10, g2 = 9')
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
plt.xlim([0,20])
plt.ylim([0,0.3])
plt.show()

my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_8.0__U0_1.0__F_7.5__R_0.0__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/4
R2 = 0.75
c = 10

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
plt.title('g1 = 10, g2 = 8')
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
plt.xlim([0,20])
plt.ylim([0,0.3])
plt.show()

my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_7.5__U0_1.0__F_7.5__R_0.0__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/4
R2 = 0.75
c = 10

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
plt.title('g1 = 10, g2 = 7.5')
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
#plt.xlim([0,20])
#plt.ylim([0,0.3])
plt.show()

# %%
my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_8.0__U0_1.0__F_7.5__R_0.5__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/4
R2 = 0.75
c = 10

plt.xlabel('$t \quad [ a\sqrt{m/V_0} ] $')
plt.ylabel('$x_1-x_2 \quad [a]$')
#plt.title('g1 = 10, g2 = 5')
#particella 2 - particella 1
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
plt.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
#plt.grid()
plt.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
plt.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
#plt.legend()

plt.text(18, 0.235*3, '$R_2$',color='orangered')
plt.text(18, 0.15*3, '$R_1$', color='forestgreen')
plt.xlim([0,20])
#plt.savefig("Prova1.pdf", dpi=300, bbox_inches='tight')
plt.show()

start = int(len(r)/5)
end = len(r)
vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.7791843217681046
# La frequenza armonica in un intorno di R2 è :  1.1324072723509584
# La barriera di potenziale è :  0.2636718750000001

# %%
import matplotlib.transforms as mtransforms
fig, (ax1, ax3) = plt.subplots(2)

my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_5.0__U0_1.0__F_7.5__R_0.0__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
r = data[:,3]-data[:,2]
ax1.plot(data[:,0], r , label='$x_1-x_2$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(13, 0.66, '$R_2$',color='orangered')
ax1.text(13, 0.34, '$R_1$',color='forestgreen')
#ax1.text(18, 0.15*3, '$R_1$', color='forestgreen')
ax1.set(ylabel=r'$x_2-x_1 \quad [a]$',ylim = [0,0.93])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0,0.93])
ax1T.set(xlim=[0,15])
ax1.set(xlim=[0,15])


my_file = pd.read_csv("output___n_2__gam1_10.0__gam2_8.0__U0_1.0__F_7.5__R_0.0__R2_0.4330127019__R3_0.75__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file)  
r = data[:,3]-data[:,2]
ax3.plot(data[:,0], r , color ='darkblue',linewidth=1)
ax3.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax3.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
#ax3.text(18, 0.235*3, '$R_2$',color='orangered')
#ax3.text(18, 0.15*3, '$R_1$', color='forestgreen')

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set(ylim = [0.0,0.24])
ax3T.set(xlim=[0,15])
ax3.set(ylabel=r'$x_2-x_1 \quad [a]$',ylim = [0.0,0.24])
ax3.set(xlabel=r'$t \quad [ a\sqrt{m/V_0} ] $',xlim=[0,15])



trans = mtransforms.ScaledTranslation(8/72, -5/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

ax3.text(0, 1.0, '(b)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))


plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig("different.pdf", dpi=300, bbox_inches='tight')
plt.show()
