# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.fft import fft, fftfreq
import matplotlib.transforms as mtransforms

# %% [markdown]
# Da risonanza_1, R1 = 0.3, R2 = 0.7, c = 1, gamma = 2, ottengo una figura molto strana. Indago regime sottosmorzato

# %%
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_2.6__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 1

start=0
end = 100000

plt.xlabel('t')
plt.ylabel('x1-x2')
#plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]

#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin

#plt.plot(data[:,0], r ,'-g.',markevery = list(np.where(r > 0.5, True, False)))
#plt.plot(data[:,0], r ,'-rD',markevery = list(np.where(r <- 0.5, True, False)))
plt.plot(data[:,0], r , '-b',label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.grid()
#plt.ylim([0.65,0.75])
#plt.xlim([40,50])
plt.title('F=2.6')
plt.show()

#forza sin(r)cos(xcm)
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

plt.xlabel('t')
plt.ylabel('F')
plt.title('2*sin(pi*r)cos(2pi*xcm)')
plt.plot(data[start:end,0], y, linewidth=0.8)
#plt.xlim([40,50])
plt.grid()
plt.show()

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.5514742624701916
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994

# %%
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_3.5__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 1

start=0
end = 50000

plt.xlabel('t')
plt.ylabel('x1-x2')
#plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]

#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin

plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
#plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.grid()
#plt.ylim([0.65,0.75])
#plt.xlim([40,50])
plt.title('F=3.5')
plt.show()


vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  1.7030853897293252
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994

# %%
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_3.2__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 1

start=0
end = 50000

plt.xlabel('t')
plt.ylabel('x1-x2')
#plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]

#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin

plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
#plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.grid()
#plt.ylim([0.65,0.75])
#plt.xlim([40,50])
plt.title('F=3.2')
plt.show()


vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  1.5450332479375612
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994

# %%
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_3.0__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 1

start=0
end = 50000

plt.xlabel('t')
plt.ylabel('x1-x2')
#plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]

#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin

plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
#plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.grid()
#plt.ylim([0.65,0.75])
#plt.xlim([40,50])
plt.title('F=3.0')
plt.show()

plt.xlabel('t')
plt.ylabel('Vcm')
plt.title('Vcm')
plt.plot(data[start:end,0], (data[start:end,4]+data[start:end,5])/2, linewidth=0.8)
plt.xlim([40,50])
plt.ylim([1.2,1.7])
plt.grid()
plt.show()

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  1.4309185815189092
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994

# %%
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_2.6__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 1

start=0
end = 100000

r = -data[:,2]+data[:,3]
xcm = (data[:,2]+data[:,3])/2

#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin


vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.plot(data[:,0], -R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], -R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(2.1, 0.8, '$R_2$',color='orangered')
ax1.text(2.1, 0.37, '$R_1$', color='forestgreen')
ax1.text(4.1, -1.02, '$-R_2$',color='orangered')
ax1.text(4.1, -0.56, '$-R_1$', color='forestgreen')
ax1.set(ylabel='$x_2 -x_1 \quad [a]$', ylim = [-1.25,1.25])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set( ylim = [-1.25,1.25])
ax1T.set(xlim=[0,15])

vcm_ = (data[:,4]+data[:,5])/2
ax2.plot(data[:,0], y , color ='darkblue',linewidth=1)
ax2.set(ylabel=r'$F_{dri}^{eff} \quad [V_0/a]$', ylim = [-6.6,6.6])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.set(xlim=[0,15])
ax2T.set(xlim=[0,15])
ax2R.set( ylim = [-6.6,6.6])


ax3.plot(data[:,0], vcm_ ,  color ='darkblue',linewidth=1)
ax3.set(ylabel=r'$v_{cm} \quad [\sqrt{V_0/m}]$', ylim = [0.2,0.95])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set(ylim = [0.2,0.95])
ax3T.set(xlim=[0,15])


trans = mtransforms.ScaledTranslation(0, 5/72, fig.dpi_scale_trans)
ax1.text(0.94, 0.12, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.94, 0.12, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0.94, 0.12, '(c)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))


ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')
plt.subplots_adjust(wspace=0, hspace=0)
plt.xlim([0,15])
plt.savefig("Underdamped.pdf", dpi=300, bbox_inches='tight')
plt.savefig("Underdamped.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# La velocità del centro di massa è :  0.5514742624701916
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994

# %% [markdown]
# In regime sottosmorzato, con barriera di potenziale piccola:
# a basse F ho oscillazioni intorno a zero!
# Dopo una certa soglia torno a normali oscillazioni intorno ai minimi o a collassi nell'origine. I primi però possono avvenire anche a particelle invertite, cosa che non succedeva mai con gamma alti, perchè per far ciò bisogna passare per zero senza collassare

# %% [markdown]
# Provo ora con c più grandi

# %%
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_2.2__R_0.7__R2_0.3__R3_0.7__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 10

start=0
end = 10000

plt.xlabel('t')
plt.ylabel('x1-x2')
#plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]
print(len(r))
#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin

plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.grid()
#plt.ylim([0.65,0.75])
plt.xlim([40,50])
plt.title('F=2.2, c = 10')
plt.show()

#forza sin(r)cos(xcm)
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

plt.xlabel('t')
plt.ylabel('F')
plt.title('2*sin(pi*r)cos(2pi*xcm)')
plt.plot(data[start:end,0], y, linewidth=0.8)
plt.xlim([40,50])
plt.grid()
plt.show()


plt.xlabel('t')
plt.ylabel('Vcm')
plt.title('Vcm')
plt.plot(data[start:end,0], (data[start:end,4]+data[start:end,5])/2, linewidth=0.8)
plt.xlim([40,50])
plt.grid()
plt.show()


vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# 10000
# La velocità del centro di massa è :  0.5075351397172254
# La frequenza armonica in un intorno di R2 è :  1.0915755217271463
# La barriera di potenziale è :  0.31999999999999995

# %%
R1 = 0.3
R2 = 0.7
c = 10
w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

Fmin = 1.8
Fmax = 2.6
df = 0.01

start=8000
end=10000

Forces = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))
Vel_cm = np.zeros(len(Forces))
Ampiezze = np.zeros(len(Forces))

i=0
for F in Forces:
    my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_"+str(F)+"__R_0.7__R2_0.3__R3_0.7__c_10.0.dat"
                      ,sep=' ')
    data = np.array(my_file)
    
    r = -data[:,2]+data[:,3]
    #calcolo ampiezza oscillazione
    rmax = np.max(r[start:end])
    rmin = np.min(r[start:end])
    A = rmax - rmin
    Ampiezze[i] = A
    
    vcm = np.mean(data[start:end,4]+data[start:end,5])/2
    Vel_cm[i] = vcm
    
    i+=1
    

plt.xlabel('Forces')
plt.ylabel('Amplitude')
plt.title('Resonance: g=2 , c=10, R=R2')
plt.plot(Forces, Ampiezze,  label='Ampiezza',linewidth=1, marker ='.')
plt.plot(Forces, Vel_cm, linewidth=1, label='vcm', marker ='.')
plt.plot(Forces, (w)*np.ones(len(Forces)), label='w',linestyle='dashed')
plt.legend()
plt.grid()
plt.xlim([1.8,2.1])
plt.show()

Max = Vel_cm[np.where(Ampiezze == np.max(Ampiezze))[0][0]]
print('Il picco di ampiezza vale:', np.max(Ampiezze))
print('Il rapporto tra la frequenza del picco e quella armonica è :' , Max/w)
  
Forces_10 = Forces
Vel_cm_10 = Vel_cm
Ampiezze_10 = Ampiezze
w_10 = w

print(Forces)
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_2.04__R_0.7__R2_0.3__R3_0.7__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file)
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
#plt.ylim([0.65,0.75])
#plt.xlim([120,150])
plt.show()
# Out:
# La frequenza armonica in un intorno di R2 è :  1.0915755217271463
# La barriera di potenziale è :  0.31999999999999995
# Il picco di ampiezza vale: 1.812904126759534
# Il rapporto tra la frequenza del picco e quella armonica è : 0.4213039450318029
# [1.8  1.81 1.82 1.83 1.84 1.85 1.86 1.87 1.88 1.89 1.9  1.91 1.92 1.93
#  1.94 1.95 1.96 1.97 1.98 1.99 2.   2.01 2.02 2.03 2.04 2.05 2.06 2.07
#  2.08 2.09 2.1  2.11 2.12 2.13 2.14 2.15 2.16 2.17 2.18 2.19 2.2  2.21
#  2.22 2.23 2.24 2.25 2.26 2.27 2.28 2.29 2.3  2.31 2.32 2.33 2.34 2.35
#  2.36 2.37 2.38 2.39 2.4  2.41 2.42 2.43 2.44 2.45 2.46 2.47 2.48 2.49
#  2.5  2.51 2.52 2.53 2.54 2.55 2.56 2.57 2.58 2.59 2.6 ]

# %%
R1 = 0.3
R2 = 0.7
c = 10
w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

Fmin = 1.8
Fmax = 2.6
df = 0.01

start=8000
end=10000

Forces = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))
Vel_cm = np.zeros(len(Forces))
Ampiezze = np.zeros(len(Forces))

i=0
for F in Forces:
    my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_"+str(F)+"__R_1.0__R2_0.3__R3_0.7__c_10.0.dat"
                      ,sep=' ')
    data = np.array(my_file)
    
    r = -data[:,2]+data[:,3]
    #calcolo ampiezza oscillazione
    rmax = np.max(r[start:end])
    rmin = np.min(r[start:end])
    A = rmax - rmin
    Ampiezze[i] = A
    
    vcm = np.mean(data[start:end,4]+data[start:end,5])/2
    Vel_cm[i] = vcm
    
    i+=1
    

plt.xlabel('Forces')
plt.ylabel('Amplitude')
plt.title('Resonance: g=2 , c=10, R=1')
plt.plot(Forces, Ampiezze,  label='Ampiezza',linewidth=1, marker ='.')
plt.plot(Forces, Vel_cm, linewidth=1, label='vcm', marker ='.')
plt.plot(Forces, (w)*np.ones(len(Forces)), label='w',linestyle='dashed')
plt.legend()
plt.grid()
plt.xlim([1.9,2.2])
plt.show()

Max = Vel_cm[np.where(Ampiezze == np.max(Ampiezze))[0][0]]
print('Il picco di ampiezza vale:', np.max(Ampiezze))
print('Il rapporto tra la frequenza del picco e quella armonica è :' , Max/w)

Forces_10_1 = Forces
Vel_cm_10_1 = Vel_cm
Ampiezze_10_1 = Ampiezze
w_10_1 = w

print(Forces)
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_2.19__R_1.0__R2_0.3__R3_0.7__c_10.0.dat"
                      ,sep=' ')
data = np.array(my_file)
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
#plt.ylim([0.65,0.75])
#plt.xlim([120,150])
plt.show()
# Out:
# La frequenza armonica in un intorno di R2 è :  1.0915755217271463
# La barriera di potenziale è :  0.31999999999999995
# Il picco di ampiezza vale: 1.8053815097359873
# Il rapporto tra la frequenza del picco e quella armonica è : 0.4121862340194053
# [1.8  1.81 1.82 1.83 1.84 1.85 1.86 1.87 1.88 1.89 1.9  1.91 1.92 1.93
#  1.94 1.95 1.96 1.97 1.98 1.99 2.   2.01 2.02 2.03 2.04 2.05 2.06 2.07
#  2.08 2.09 2.1  2.11 2.12 2.13 2.14 2.15 2.16 2.17 2.18 2.19 2.2  2.21
#  2.22 2.23 2.24 2.25 2.26 2.27 2.28 2.29 2.3  2.31 2.32 2.33 2.34 2.35
#  2.36 2.37 2.38 2.39 2.4  2.41 2.42 2.43 2.44 2.45 2.46 2.47 2.48 2.49
#  2.5  2.51 2.52 2.53 2.54 2.55 2.56 2.57 2.58 2.59 2.6 ]

# %%
R1 = 0.3
R2 = 0.7
c = 1
w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

Fmin = 1.7
Fmax = 3.5
df = 0.05

start=4000
end=5000

Forces = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1 ))
Vel_cm = np.zeros(len(Forces))
Ampiezze = np.zeros(len(Forces))
#print(Forces)

i=0
for F in Forces:
    my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_"+str(F)+"__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
    data = np.array(my_file)
    
    r = -data[:,2]+data[:,3]
    #calcolo ampiezza oscillazione
    rmax = np.max(r[start:end])
    rmin = np.min(r[start:end])
    A = rmax - rmin
    Ampiezze[i] = A
    
    vcm = np.mean(data[start:end,4]+data[start:end,5])/2
    Vel_cm[i] = vcm
    
    i+=1
    

plt.xlabel('Forces')
plt.ylabel('Amplitude')
plt.title('Resonance: g=2 , c=1, R=0.7')
plt.plot(Forces, Ampiezze,  label='Ampiezza',linewidth=1, marker ='.')
plt.plot(Forces, Vel_cm, linewidth=1, label='vcm', marker ='.')
plt.plot(Forces, (w)*np.ones(len(Forces)), label='w',linestyle='dashed')
plt.legend()
plt.grid()
#plt.xlim([1.8,2.6])
plt.show()

Max = Vel_cm[np.where(Ampiezze == np.max(Ampiezze))[0][0]]
print('Il picco di ampiezza vale:', np.max(Ampiezze))
print('Il rapporto tra la frequenza del picco e quella armonica è :' , Max/w)

Forces_1 = Forces
Vel_cm_1 = Vel_cm
Ampiezze_1 = Ampiezze
w_1 = w

print(Forces)
my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_3.45__R_0.7__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
#plt.ylim([0.65,0.75])
#plt.xlim([120,150])
plt.show()
# Out:
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994
# Il picco di ampiezza vale: 2.1496047039594046
# Il rapporto tra la frequenza del picco e quella armonica è : 1.762635148596486
# [1.7  1.75 1.8  1.85 1.9  1.95 2.   2.05 2.1  2.15 2.2  2.25 2.3  2.35
#  2.4  2.45 2.5  2.55 2.6  2.65 2.7  2.75 2.8  2.85 2.9  2.95 3.   3.05
#  3.1  3.15 3.2  3.25 3.3  3.35 3.4  3.45 3.5 ]

# %%
# R = 0.3, 1
R1 = 0.3
R2 = 0.7
c = 1
w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

Fmin = 1.7
Fmax = 3.5
df = 0.05

start=4000
end=5000

Forces = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1 ))
Vel_cm = np.zeros(len(Forces))
Ampiezze = np.zeros(len(Forces))
#print(Forces)

i=0
for F in Forces:
    my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_"+str(F)+"__R_1.0__R2_0.3__R3_0.7__c_1.0.dat"
                      ,sep=' ')
    data = np.array(my_file)
    
    r = -data[:,2]+data[:,3]
    #calcolo ampiezza oscillazione
    rmax = np.max(r[start:end])
    rmin = np.min(r[start:end])
    A = rmax - rmin
    Ampiezze[i] = A
    
    vcm = np.mean(data[start:end,4]+data[start:end,5])/2
    Vel_cm[i] = vcm
    
    i+=1
    

plt.xlabel('Forces')
plt.ylabel('Amplitude')
plt.title('Resonance: g=2 , c=1, R=1')
plt.plot(Forces, Ampiezze,  label='Ampiezza',linewidth=1, marker ='.')
plt.plot(Forces, Vel_cm, linewidth=1, label='vcm', marker ='.')
plt.plot(Forces, (w)*np.ones(len(Forces)), label='w',linestyle='dashed')
plt.legend()
plt.grid()
#plt.xlim([1.8,2.6])
plt.show()

Max = Vel_cm[np.where(Ampiezze == np.max(Ampiezze))[0][0]]
print('Il picco di ampiezza vale:', np.max(Ampiezze))
print('Il rapporto tra la frequenza del picco e quella armonica è :' , Max/w)
    
Forces_1_1 = Forces
Vel_cm_1_1 = Vel_cm
Ampiezze_1_1 = Ampiezze
w_1_1 = w
# Out:
# La frequenza armonica in un intorno di R2 è :  0.34518648867443985
# La barriera di potenziale è :  0.031999999999999994
# Il picco di ampiezza vale: 2.1604848699900607
# Il rapporto tra la frequenza del picco e quella armonica è : 1.8036106744657283

# %%
R1 = 0.3
R2 = 0.7
c = 100
w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)


Fmin = 2
Fmax = 5.5
df = 0.1
Forces1 = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))

Fmin = 5.5
Fmax = 7
df = 0.01
Forces2 = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))

Fmin = 7
Fmax = 9
df = 0.1
Forces3 = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))

Forces = np.concatenate((Forces1,Forces2, Forces3))


start=8000
end=10000

#Forces = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))
Vel_cm = np.zeros(len(Forces))
Ampiezze = np.zeros(len(Forces))

i=0
for F in Forces:
    my_file = pd.read_csv("output___n_2__gam_2.0__U0_1.0__F_"+str(F)+"__R_0.7__R2_0.3__R3_0.7__c_100.0.dat"
                      ,sep=' ')
    data = np.array(my_file)
    
    r = -data[:,2]+data[:,3]
    #calcolo ampiezza oscillazione
    rmax = np.max(r[start:end])
    rmin = np.min(r[start:end])
    A = rmax - rmin
    Ampiezze[i] = A
    
    vcm = np.mean(data[start:end,4]+data[start:end,5])/2
    Vel_cm[i] = vcm
    
    i+=1
    
plt.xlabel('Forces')
plt.ylabel('Amplitude')
plt.title('Resonance: g=2 , c=100')
plt.plot(Forces, Ampiezze,  label='Ampiezza',linewidth=1, marker ='.')
#plt.plot([w,w], [0,0.5], label = 'w', linestyle = 'dashed')
plt.legend()
plt.grid()
#plt.xlim([2.4,4])
#plt.ylim([0,0.3])
plt.show()

Max = Vel_cm[np.where(Ampiezze == np.max(Ampiezze))[0][0]]
print('Il picco di ampiezza vale:', np.max(Ampiezze))
print('Il rapporto tra la frequenza del picco e quella armonica è :' , Max/w)
    
Forces_100 = Forces
Vel_cm_100 = Vel_cm
Ampiezze_100 = Ampiezze
w_100 = w
# Out:
# La frequenza armonica in un intorno di R2 è :  3.4518648867443984
# La barriera di potenziale è :  3.1999999999999993
# Il picco di ampiezza vale: 0.28071077632216657
# Il rapporto tra la frequenza del picco e quella armonica è : 0.8274251134448735

# %% [raw]
# fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2,2)
#
# ax1.plot(Forces_0_001, Ampiezze_0_001 , color ='darkblue',linewidth=1, marker ='.')
# ax1.set(ylabel='$Amplitude \quad [a]$', ylim = [0,0.85],xlim=[2,8.2])
#
# ax1R = ax1.twinx()
# ax1T = ax1.twiny()
# ax1.tick_params(direction='in')
# ax1T.tick_params(direction='in')
# ax1R.tick_params(direction='in')
# ax1R.yaxis.set_major_formatter(plt.NullFormatter())
# ax1T.xaxis.set_major_formatter(plt.NullFormatter())
# ax1R.set(ylim = [0,0.85])
# ax1T.set(xlim=[2,8.2],xlabel='(a)')
#
#
#
# ax2.plot(Vel_cm_0_001, Ampiezze_0_001 , color ='darkblue',linewidth=1, marker ='.')
# ax2.plot([w_0_001,w_0_001], [0,1],color='orangered', label = 'w', linestyle = 'dashed')
# ax2.text(0.115, 0.1, r'$v_{R_2}$',color='orangered')
# ax2.set(ylim = [0,0.85],xlim=[-0.1,1.6])
#
# ax2R = ax2.twinx()
# ax2T = ax2.twiny()
# ax2.tick_params(direction='in')
# ax2T.tick_params(direction='in')
# ax2R.tick_params(direction='in')
# ax2.yaxis.set_major_formatter(plt.NullFormatter())
# ax2R.yaxis.set_major_formatter(plt.NullFormatter())
# ax2T.xaxis.set_major_formatter(plt.NullFormatter())
# ax2T.set(xlim=[-0.1,1.6],xlabel='(b)')
# ax2R.set(ylim = [0,0.85])
#
#
#
# ax3.plot(Forces_0_01, Ampiezze_0_01 , color ='darkblue',linewidth=1, marker ='.')
# ax3.set(ylabel='$Amplitude \quad [a]$', ylim = [0,0.85],xlim=[2,8.2])
#
# ax3R = ax3.twinx()
# ax3T = ax3.twiny()
# ax3.tick_params(direction='in')
# ax3T.tick_params(direction='in')
# ax3R.tick_params(direction='in')
# ax3R.yaxis.set_major_formatter(plt.NullFormatter())
# ax3T.xaxis.set_major_formatter(plt.NullFormatter())
# ax3R.set( ylim = [0,0.85])
# ax3T.set(xlim=[2,8.2],xlabel='(c)')
# ax3.set(xlabel=r'$F \quad [V_0/a] $')
#
# ax4.plot(Vel_cm_0_01, Ampiezze_0_01 , color ='darkblue',linewidth=1, marker ='.')
# ax4.plot([w_0_01,w_0_01], [0,1],color='orangered', label = 'w', linestyle = 'dashed')
# ax4.text(0.35, 0.15, r'$v_{R_2}$',color='orangered')
# ax4.set(ylim = [0,0.85],xlim=[-0.1,1.6])
#
# ax4R = ax4.twinx()
# ax4T = ax4.twiny()
# ax4.tick_params(direction='in')
# ax4T.tick_params(direction='in')
# ax4R.tick_params(direction='in')
# ax4.yaxis.set_major_formatter(plt.NullFormatter())
# ax4R.yaxis.set_major_formatter(plt.NullFormatter())
# ax4T.xaxis.set_major_formatter(plt.NullFormatter())
# ax4T.set(xlim=[-0.1,1.6],xlabel='(d)')
# ax4R.set(ylim = [0,0.85])
# ax4.set(xlabel=r'$\bar{v}_{cm} \quad [\sqrt{V_0/m}] $')
#
# plt.subplots_adjust(wspace=0, hspace = 0.3)
# plt.savefig("Underdamped_res.pdf", dpi=300, bbox_inches='tight')
# plt.show()

# %%
my_file = pd.read_csv("output___n_2__gam_0.5__U0_1.0__F_1.55__R_0.7__R2_0.3__R3_0.7__c_100.0.dat"
                      ,sep=' ')
data = np.array(my_file)

R1 = 0.3
R2 = 0.7
c = 100

start=12000
end=15000

plt.xlabel('t')
plt.ylabel('x1-x2')
#plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]

#calcolo ampiezza oscillazione
rmax = np.max(r[start:end])
rmin = np.min(r[start:end])
A = rmax - rmin

plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
#plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.grid()
#plt.ylim([0.65,0.75])
#plt.xlim([40,50])
plt.title('F=1.55, c = 100')
plt.show()


vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  3.096103586151989
# La frequenza armonica in un intorno di R2 è :  3.4518648867443984
# La barriera di potenziale è :  3.1999999999999993

# %%
R1 = 0.3
R2 = 0.7
c = 100
w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)

Fmin = 0.5
Fmax = 1.3
df = 0.05
Forces1 = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))

Fmin = 1.3
Fmax = 2
df = 0.01
Forces2 = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))

Fmin = 2
Fmax = 3
df = 0.05
Forces3 = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))

Forces = np.concatenate((Forces1,Forces2, Forces3))

Fmin = 0.5
Fmax = 3
df = 0.05

start=14000
end=15000

#Forces = np.linspace(Fmin, Fmax , int((Fmax-Fmin)/df +1))
Vel_cm = np.zeros(len(Forces))
Ampiezze = np.zeros(len(Forces))

i=0
for F in Forces:
    my_file = pd.read_csv("output___n_2__gam_0.5__U0_1.0__F_"+str(F)+"__R_0.7__R2_0.3__R3_0.7__c_100.0.dat"
                      ,sep=' ')
    data = np.array(my_file)
    
    r = -data[:,2]+data[:,3]
    #calcolo ampiezza oscillazione
    rmax = np.max(r[start:end])
    rmin = np.min(r[start:end])
    A = rmax - rmin
    Ampiezze[i] = A
    
    vcm = np.mean(data[start:end,4]+data[start:end,5])/2
    Vel_cm[i] = vcm
    
    i+=1
    

plt.xlabel('Vel_cm')
plt.ylabel('Amplitude')
plt.title('Resonance: g=0.5 , c=100')
plt.plot(Vel_cm, Ampiezze,  label='Ampiezza',linewidth=1, marker ='.')
plt.plot([w,w], [0,0.5], label = 'w', linestyle = 'dashed')
plt.legend()
plt.grid()
#plt.xlim([0.9,1.5])
#plt.ylim([0,0.3])
plt.show()

Max = Vel_cm[np.where(Ampiezze == np.max(Ampiezze))[0][0]]
print('Il picco di ampiezza vale:', np.max(Ampiezze))
print('Il rapporto tra la frequenza del picco e quella armonica è :' , Max/w)
  
Forces_100_b = Forces
Vel_cm_100_b = Vel_cm
Ampiezze_100_b = Ampiezze
w_100_b = w
# Out:
# La frequenza armonica in un intorno di R2 è :  3.4518648867443984
# La barriera di potenziale è :  3.1999999999999993
# Il picco di ampiezza vale: 0.33061324789468927
# Il rapporto tra la frequenza del picco e quella armonica è : 0.7923422926087494

# %%
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2,2)

ax1.plot(Forces_1, Ampiezze_1 , color ='darkblue',linewidth=0.8, marker ='.')
ax1.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.1,2.35],xlim=[1.6,3.6])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [-0.1,2.35])
ax1T.set(xlim=[1.6,3.6],xlabel=r'$U = 1 V_0/a^6$')



ax2.plot(Forces_10, Ampiezze_10 , color ='darkblue',linewidth=0.8, marker ='.')
ax2.set(ylim = [-0.1,1.95],xlim=[1.78,2.62])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[1.78,2.62],xlabel=r'$U = 10 V_0/a^6$')
ax2R.set(ylim = [-0.1,1.95])



ax3.plot(Forces_1_1, Ampiezze_1_1 , color ='darkblue',linewidth=0.8, marker ='.')
ax3.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.1,2.35],xlim=[1.6,3.6])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set( ylim = [-0.1,2.35])
ax3T.set(xlim=[1.6,3.6])
ax3.set(xlabel=r'$F \quad [V_0/a] $')

ax4.plot(Forces_10_1, Ampiezze_10_1 , color ='darkblue',linewidth=0.8, marker ='.')
ax4.set(ylim = [-0.1,1.95],xlim=[1.78,2.62])

ax4R = ax4.twinx()
ax4T = ax4.twiny()
ax4.tick_params(direction='in')
ax4T.tick_params(direction='in')
ax4R.tick_params(direction='in')
#ax4.yaxis.set_major_formatter(plt.NullFormatter())
ax4R.yaxis.set_major_formatter(plt.NullFormatter())
ax4T.xaxis.set_major_formatter(plt.NullFormatter())
ax4T.set(xlim=[1.78,2.62])
ax4R.set(ylim = [-0.1,1.95])
ax4.set(xlabel=r'$F \quad [V_0/a] $')

trans = mtransforms.ScaledTranslation(6/72, -5/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0, 1.0, '(c)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0, 1.0, '(b)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax4.text(0, 1.0, '(d)', transform=ax4.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))


plt.subplots_adjust(hspace = 0)
plt.savefig("Underdamped_res.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2,2)

ax1.plot(Forces_100, Ampiezze_100 , color ='darkblue',linewidth=1, marker ='.')
ax1.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.01,0.3],xlim=[1.8,9.2])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [-0.01,0.3])
ax1T.set(xlim=[1.8,9.2])



ax2.plot(Vel_cm_100, Ampiezze_100 , color ='darkblue',linewidth=1, marker ='.')
ax2.plot([w_100,w_100], [0,1],color='orangered', label = 'w', linestyle = 'dashed')
ax2.text(3.5, 0.2, r'$v_{harm}$',color='orangered')
ax2.set(ylim = [-0.01,0.3],xlim=[0.8,4.6])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[-0.1,1.8])
ax2R.set(ylim = [-0.01,0.3])



ax3.plot(Forces_100_b, Ampiezze_100_b , color ='darkblue',linewidth=1, marker ='.')
ax3.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.01,0.35],xlim=[0.4,2.9])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set( ylim = [-0.01,0.35])
ax3T.set(xlim=[0.4,2.9])
ax3.set(xlabel=r'$F \quad [V_0/a] $')

ax4.plot(Vel_cm_100_b, Ampiezze_100_b , color ='darkblue',linewidth=1, marker ='.')
ax4.plot([w_100_b,w_100_b], [0,1],color='orangered', label = 'w', linestyle = 'dashed')
ax4.text(3.5, 0.25, r'$v_{harm}$',color='orangered')
ax4.set(ylim = [-0.01,0.35],xlim=[-0.2,6.2])

ax4R = ax4.twinx()
ax4T = ax4.twiny()
ax4.tick_params(direction='in')
ax4T.tick_params(direction='in')
ax4R.tick_params(direction='in')
ax4.yaxis.set_major_formatter(plt.NullFormatter())
ax4R.yaxis.set_major_formatter(plt.NullFormatter())
ax4T.xaxis.set_major_formatter(plt.NullFormatter())
ax4T.set(xlim=[-0.2,6.2])
ax4R.set(ylim = [-0.01,0.35])
ax4.set(xlabel=r'$\bar{v}_{cm} \quad [\sqrt{V_0/m}] $')

trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0, 1.0, '(c)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax4.text(0, 1.0, '(d)', transform=ax4.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.subplots_adjust(wspace=0)
plt.savefig("Underdamped_res_2.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2,2)
print(len(Ampiezze_1))

ax1.plot(Forces_1, Ampiezze_1 , color ='orangered',linewidth=0, marker ='^',markersize=5,markevery = list(np.where(Ampiezze_1 > 1.5, True, False)))
ax1.plot(Forces_1, Ampiezze_1 , color ='darkblue',linewidth=0, marker ='.',markevery = list(np.where( Ampiezze_1 <1.5, True, False)))
ax1.plot(Forces_1[0:20], Ampiezze_1[0:20] , color ='black',linewidth=0, marker ='v',markersize=5,markevery = list(np.where(Ampiezze_1[0:20] <0.05, True, False)))
ax1.plot(Forces_1[20:], Ampiezze_1[20:] , color ='forestgreen',linewidth=0, marker ='d',markersize=5,markevery = list(np.where(Ampiezze_1[20:] <0.05, True, False)))
ax1.plot(Forces_1, Ampiezze_1 , color ='darkblue',linewidth=0.8)
ax1.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.1,2.35],xlim=[1.6,3.6])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [-0.1,2.35])
ax1T.set(xlim=[1.6,3.6],xlabel=r'$U = 1 V_0/a^6$')


ax2.plot(Forces_10, Ampiezze_10 , color ='orangered',linewidth=0, marker ='^',markersize=5,markevery = list(np.where(Ampiezze_10 > 1.5, True, False)))
ax2.plot(Forces_10[20:50], Ampiezze_10[20:50], color ='darkmagenta',linewidth=0, marker ='<',markevery = list(np.where( Ampiezze_10[20:50] <1.5, True, False)))
ax2.plot(Forces_10[0:20], Ampiezze_10[0:20] , color ='black',linewidth=0, marker ='v',markersize=5,markevery = list(np.where(Ampiezze_10[0:20] <0.05, True, False)))
ax2.plot(Forces_10[20:], Ampiezze_10[20:] , color ='forestgreen',linewidth=0, marker ='d',markersize=5,markevery = list(np.where(Ampiezze_10[20:] <0.05, True, False)))
ax2.plot(Forces_10, Ampiezze_10 , color ='darkblue',linewidth=0.8)
ax2.set(ylim = [-0.1,1.95],xlim=[1.78,2.62])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[1.78,2.62],xlabel=r'$U = 10 V_0/a^6$')
ax2R.set(ylim = [-0.1,1.95])



ax3.plot(Forces_1_1, Ampiezze_1_1 , color ='orangered',linewidth=0, marker ='^',markersize=5,markevery = list(np.where(Ampiezze_1_1 > 1.5, True, False)))
ax3.plot(Forces_1_1, Ampiezze_1_1 , color ='darkblue',linewidth=0, marker ='.',markevery = list(np.where( Ampiezze_1_1 <1.5, True, False)))
ax3.plot(Forces_1_1[0:20], Ampiezze_1_1[0:20] , color ='black',linewidth=0, marker ='v',markersize=5,markevery = list(np.where(Ampiezze_1_1[0:20] <0.05, True, False)))
ax3.plot(Forces_1_1[20:], Ampiezze_1_1[20:] , color ='forestgreen',linewidth=0, marker ='d',markersize=5,markevery = list(np.where(Ampiezze_1_1[20:] <0.05, True, False)))
ax3.plot(Forces_1_1, Ampiezze_1_1 , color ='darkblue',linewidth=0.8)
ax3.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.1,2.35],xlim=[1.6,3.6])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set( ylim = [-0.1,2.35])
ax3T.set(xlim=[1.6,3.6])
ax3.set(xlabel=r'$F \quad [V_0/a] $')

ax4.plot(Forces_10_1, Ampiezze_10_1 , color ='orangered',linewidth=0, marker ='^',markersize=5,markevery = list(np.where(Ampiezze_10_1 > 1.5, True, False)))
ax4.plot(Forces_10_1[20:50], Ampiezze_10_1[20:50], color ='darkmagenta',linewidth=0, marker ='<',markevery = list(np.where( Ampiezze_10_1[20:50] <1.5, True, False)))
ax4.plot(Forces_10_1[0:20], Ampiezze_10_1[0:20] , color ='black',linewidth=0, marker ='v',markersize=5,markevery = list(np.where(Ampiezze_10_1[0:20] <0.05, True, False)))
ax4.plot(Forces_10_1[20:], Ampiezze_10_1[20:] , color ='forestgreen',linewidth=0, marker ='d',markersize=5,markevery = list(np.where(Ampiezze_10_1[20:] <0.0005, True, False)))
ax4.plot(Forces_10_1, Ampiezze_10_1 , color ='darkblue',linewidth=0.8)
ax4.set(ylim = [-0.1,1.95],xlim=[1.78,2.62])

ax4R = ax4.twinx()
ax4T = ax4.twiny()
ax4.tick_params(direction='in')
ax4T.tick_params(direction='in')
ax4R.tick_params(direction='in')
#ax4.yaxis.set_major_formatter(plt.NullFormatter())
ax4R.yaxis.set_major_formatter(plt.NullFormatter())
ax4T.xaxis.set_major_formatter(plt.NullFormatter())
ax4T.set(xlim=[1.78,2.62])
ax4R.set(ylim = [-0.1,1.95])
ax4.set(xlabel=r'$F \quad [V_0/a] $')

trans = mtransforms.ScaledTranslation(6/72, -5/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0, 1.0, '(c)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0, 1.0, '(b)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax4.text(0, 1.0, '(d)', transform=ax4.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))


plt.subplots_adjust(hspace = 0)
plt.savefig("Underdamped_res_col.pdf", dpi=300, bbox_inches='tight')
plt.savefig("Underdamped_res_col.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 37

# %%
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2,2)

ax1.plot(Forces_100, Ampiezze_100 , color ='darkblue',linewidth=1, marker ='.')
ax1.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.01,0.3],xlim=[1.8,9.2])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [-0.01,0.3])
ax1T.set(xlim=[1.8,9.2])



ax2.plot(Vel_cm_100, Ampiezze_100 , color ='darkblue',linewidth=1, marker ='.')
ax2.plot([w_100,w_100], [-1,1],color='orangered', label = 'w', linestyle = 'dashed')
ax2.text(3.5, 0.2, r'$v_{harm}$',color='orangered')
ax2.set(ylim = [-0.01,0.3],xlim=[0.8,4.6])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[-0.1,1.8])
ax2R.set(ylim = [-0.01,0.3])


ax3.plot(Forces_100_b[:20], Ampiezze_100_b[:20], color ='black',linewidth=0, marker ='v',markersize=5,markevery = list(np.where(Ampiezze_100_b[:20] <0.0005, True, False)))
ax3.plot(Forces_100_b[20:], Ampiezze_100_b[20:], color ='forestgreen',linewidth=0, marker ='d',markersize=3,markevery = list(np.where(Ampiezze_100_b[20:] <0.0005, True, False)))
ax3.plot(Forces_100_b, Ampiezze_100_b, color ='darkblue',linewidth=0, marker ='.',markevery = list(np.where(Ampiezze_100_b >0.0005, True, False)))
ax3.plot(Forces_100_b, Ampiezze_100_b , color ='darkblue',linewidth=0.8)
ax3.set(ylabel='$Amplitude \quad [a]$', ylim = [-0.01,0.35],xlim=[0.4,2.9])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set( ylim = [-0.01,0.35])
ax3T.set(xlim=[0.4,2.9])
ax3.set(xlabel=r'$F \quad [V_0/a] $')

ax4.plot(Vel_cm_100_b[:20], Ampiezze_100_b[:20], color ='black',linewidth=0, marker ='v',markersize=5,markevery = list(np.where(Ampiezze_100_b[:20] <0.0005, True, False)))
ax4.plot(Vel_cm_100_b[20:], Ampiezze_100_b[20:], color ='forestgreen',linewidth=0, marker ='d',markersize=3,markevery = list(np.where(Ampiezze_100_b[20:] <0.0005, True, False)))
ax4.plot(Vel_cm_100_b, Ampiezze_100_b, color ='darkblue',linewidth=0, marker ='.',markevery = list(np.where(Ampiezze_100_b >0.0005, True, False)))
ax4.plot(Vel_cm_100_b, Ampiezze_100_b , color ='darkblue',linewidth=0.5)
ax4.plot([w_100_b,w_100_b], [-1,1],color='orangered', label = 'w', linestyle = 'dashed')
ax4.text(3.5, 0.25, r'$v_{harm}$',color='orangered')
ax4.set(ylim = [-0.01,0.35],xlim=[-0.2,6.2])

ax4R = ax4.twinx()
ax4T = ax4.twiny()
ax4.tick_params(direction='in')
ax4T.tick_params(direction='in')
ax4R.tick_params(direction='in')
ax4.yaxis.set_major_formatter(plt.NullFormatter())
ax4R.yaxis.set_major_formatter(plt.NullFormatter())
ax4T.xaxis.set_major_formatter(plt.NullFormatter())
ax4T.set(xlim=[-0.2,6.2])
ax4R.set(ylim = [-0.01,0.35])
ax4.set(xlabel=r'$\bar{v}_{cm} \quad [\sqrt{V_0/m}] $')

trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0, 1.0, '(c)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax4.text(0, 1.0, '(d)', transform=ax4.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.subplots_adjust(wspace=0)
plt.savefig("Underdamped_res_2_col.pdf", dpi=300, bbox_inches='tight')
plt.savefig("Underdamped_res_2_col.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2)

ax1.plot(Vel_cm_100 , Forces_100, color ='darkblue',linewidth=0.8, marker ='.')
ax1.set(ylabel=r'$F \quad [V_0/a] $', ylim = [5.3,7.2],xlim=[2.7,3.4])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [5.3,7.2])
ax1T.set(xlim=[2.7,3.4])



ax2.plot(Vel_cm_100_b , Forces_100_b, color ='darkblue',linewidth=0.8)
ax2.plot(Vel_cm_100_b[20:], Forces_100_b[20:], color ='forestgreen',linewidth=0, marker ='d',markersize=4,markevery = list(np.where(Ampiezze_100_b[20:] <0.0005, True, False)))
ax2.plot(Vel_cm_100_b, Forces_100_b, color ='darkblue',linewidth=0, marker ='.',markevery = list(np.where(Ampiezze_100_b >0.0005, True, False)))
#ax2.plot([w_100,w_100], [0,100],color='orangered', label = 'w', linestyle = 'dashed')
#ax2.text(3.5, 0.2, r'$v_{harm}$',color='orangered')
ax2.set(ylabel=r'$F \quad [V_0/a] $', ylim = [1.35,1.83],xlim=[2.7,3.4])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.set(ylim = [1.35,1.83])
ax2T.set(xlim=[2.7,3.4])

ax2.set(xlabel=r'$\bar{v}_{cm} \quad [\sqrt{V_0/m}] $')

trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.subplots_adjust(hspace=0)
plt.savefig("Bistability.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ((ax1), (ax2)) = plt.subplots(1,2)

ax1.plot(Forces_100 , Vel_cm_100, color ='darkblue',linewidth=0.8, marker ='.')
ax1.set(ylabel=r'$\bar{v}_{cm} \quad [\sqrt{V_0/m}] $', xlim = [5.5,6.99],ylim=[2.71,3.39])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1.set(xticks=(5.75,6.25,6.75))
ax1T.set(xticks=(5.75,6.25,6.75))
ax1R.set(ylim=[2.71,3.39])
ax1T.set(xlim = [5.5,6.99])
ax1.set(xlabel=r'$F \quad [V_0/a] $')


ax2.plot(Forces_100_b, Vel_cm_100_b , color ='darkblue',linewidth=0.8)
ax2.plot( Forces_100_b[20:], Vel_cm_100_b[20:],color ='forestgreen',linewidth=0, marker ='d',markersize=4,markevery = list(np.where(Ampiezze_100_b[20:] <0.0005, True, False)))
ax2.plot( Forces_100_b, Vel_cm_100_b, color ='darkblue',linewidth=0, marker ='.',markevery = list(np.where(Ampiezze_100_b >0.0005, True, False)))
#ax2.plot([w_100,w_100], [0,100],color='orangered', label = 'w', linestyle = 'dashed')
#ax2.text(3.5, 0.2, r'$v_{harm}$',color='orangered')
ax2.set( xlim = [1.35,1.77],ylim=[2.71,3.39])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.set(ylim = [2.71,3.39])
ax2T.set(xlim=[1.35,1.77])

ax2.set(xlabel=r'$F \quad [V_0/a] $')

trans = mtransforms.ScaledTranslation(10/72, -7/72, fig.dpi_scale_trans)
ax1.text(0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.subplots_adjust(wspace=0)
plt.savefig("Bistability_2.pdf", dpi=300, bbox_inches='tight')
plt.savefig("Bistability_2.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Con una barriera di potenziale alta nessuna strana oscillazione, ma breve inversione della monotonia di vcm in funzione di F in corrispondenza del picco di risonanza
