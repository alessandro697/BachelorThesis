# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.transforms as mtransforms

# %%
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.25__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 1
r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)


#xcm e r  e vcm nella sullo stesso grafico
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=0.4)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(10, 0.21, '$R_2$',color='orangered')
ax1.text(10, 0.16, '$R_1$', color='forestgreen')
ax1.set(ylabel='$x_2-x_1 \quad [a]$', ylim = [0.11,0.45])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.11,0.45])
ax1T.set(xlim=[0,200])

ax2.plot(data[:,0], xcm , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax2.set(ylabel='$x_{cm} \quad [a]$', ylim = [0.1,149])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2R.set(xlim=[0,200])
ax2T.set(xlim=[0,200])
ax2R.set( ylim = [0.1,149])

vcm = (data[:,4]+data[:,5])/2

ax3.plot(data[:,0], vcm , label='$v_{cm}$', color ='darkblue',linewidth=0.4)
ax3.set(ylabel='$v_{cm} \quad [\sqrt{V_0/m}]$', ylim = [0.45,0.99])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set(ylim = [0.45,0.99])
ax3T.set(xlim=[0,200])


trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0.0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0.0, 1.0, '(c)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')
plt.subplots_adjust(wspace=0, hspace=0)
plt.xlim([0,200])
plt.savefig("11_a_R_Xcm.pdf", dpi=300, bbox_inches='tight')
plt.savefig("11_a_R_Xcm.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# La barriera di potenziale è :  3.616898148148148e-05

# %%
#r e forzante sullo stesso grafico

f = -2*np.pi*np.sin(np.pi*r)*np.cos(np.pi*xcm*2)

fig, (ax1, ax2) = plt.subplots(2, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(407.7, 0.223, '$R_2$',color='orangered')
ax1.text(408.4, 0.155, '$R_1$', color='forestgreen')
ax1.set(ylabel='$r \quad [a]$', ylim = [0.11,0.3])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.11,0.3])
ax1T.set(xlim=[400,410])
ax1R.set(xlim=[400,410])


ax2.plot(data[:,0], f , label='$2\sin(\pir) \cos(2\pi x_{cm})$', color ='darkblue',linewidth=1)
ax2.set(ylabel=r'$F_{dri}^{eff} \quad [V_0/a]$',ylim = [-5,4.9])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[400,410])
ax2R.set(xlim=[400,410])
ax2R.set(ylim = [-5,4.9])

ax2.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')

#ax1.annotate("(a)", xy=(0.9, 0.9), xycoords="axes fraction")
#ax2.annotate("(b)", xy=(0.9, 0.9), xycoords="axes fraction")


trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0.0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.xlim([400,410])
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_a_R_Forzante.pdf", dpi=300, bbox_inches='tight')
plt.show()



start=4000
end=5000

# %%
from scipy.fft import fft, fftfreq


my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.25__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 1
r = data[:,3]-data[:,2]
print(len(r))
xcm = (data[:,3]+data[:,2])/2
start=40000
end=50000
#forza sin(r)cos(xcm)
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2)), 1/2)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

R = fft(r[start:end])
freqr = fftfreq(end-start)*100/vcm
plt.plot(freqr, np.abs(R),label='frequency')
#plt.plot([vcm,vcm],[0,50],label='Vcm',linestyle='dashed')

plt.xlim([0.4,2.5])
plt.ylim([0,360])
plt.show()

Y = fft(y)
freqr = fftfreq(len(y))*100/vcm
plt.plot(freqr, np.abs(Y),label='frequency')
#plt.plot([vcm,vcm],[0,1600],label='Vcm',linestyle='dashed')
plt.xlim([0.4,2.5])
plt.ylim([0,17400])
plt.show()
# Out:
# 300000
# La velocità del centro di massa è :  0.6928853429000719
# La frequenza armonica in un intorno di R2 è :  0.1767766952966369

# %%
import scipy.integrate

my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.25__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
R1 = np.sqrt(3)/12
R2 = 0.25
c = 1
r = data[:,3]-data[:,2]
print(len(r))
import scipy.integrate

start = 48000
end = 50000
#calcolo energia immessa
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))
P = y*(-data[start:end,4]+data[start:end,5])
energy = scipy.integrate.trapz(P, data[start:end,0])
print(energy)
spaces = np.arange(100)
e1 = np.zeros(100)

for i in spaces:
    term = int(start + (i+1)*(end-start)/len(spaces))
    e1[i] = scipy.integrate.trapz(P[:int((i+1)*(end-start)/len(spaces))], data[start:term,0])
    
term = start + (spaces+1)*(end-start)/len(spaces)
plt.xlabel('T')
plt.ylabel('W')
plt.title('Exact work')
plt.plot(term,e1,linewidth=1)
plt.grid()
plt.show()
print(e1[:10])
# Out:
# 300000
# 11.566728750395757
# [9.12355740e-04 6.29880012e-02 2.55936542e-01 3.94285883e-01
#  4.43414859e-01 7.26399778e-01 8.30920656e-01 8.32193217e-01
#  8.72878864e-01 1.03792729e+00]

# %%
#ora con approssimazione cos(wt)
vcm = np.mean(data[30000:50000,4]+data[30000:50000,5])/2
print(vcm)
y2 = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start,2]+data[start,3]+2*vcm*data[0:end-start,0]))




P2 = y2*(-data[start:end,4]+data[start:end,5])
energy2 = scipy.integrate.trapz(P2, data[start:end,0])
print(energy2)
e2 = np.zeros(100)

for i in spaces:
    term = int(start + (i+1)*(end-start)/len(spaces))
    e2[i] = scipy.integrate.trapz(P2[:int((i+1)*(end-start)/len(spaces))], data[start:term,0])
    
term = start + (spaces+1)*(end-start)/len(spaces)
plt.xlabel('T')
plt.ylabel('W')
plt.title('Approximate work')
plt.plot(term,e2,linewidth=1)
plt.grid()
plt.show()


plt.xlabel('T')
plt.ylabel('(W2-W1)/(W2+W1)')
plt.title('Normalized Difference')
plt.plot(term,(-e2+e1)/(e2+e1),linewidth=1)
plt.grid()
plt.show()
# Out:
# 0.6929554865982731
# 9.429992120402193

# %% [raw]
# from matplotlib.gridspec import GridSpec
#
#
# fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
#
# ax1.plot(term/100,e1, color ='darkblue',linewidth=1)
#
# ax1.set(ylabel=r'$W_{ex} \quad [V_0]$', ylim = [0.1,13])
#
# ax1R = ax1.twinx()
# ax1T = ax1.twiny()
# ax1.tick_params(direction='in')
# ax1T.tick_params(direction='in')
# ax1R.tick_params(direction='in')
# ax1R.yaxis.set_major_formatter(plt.NullFormatter())
# ax1T.xaxis.set_major_formatter(plt.NullFormatter())
# ax1R.set(ylabel='(a)',ylim = [0.1,13])
# ax1T.set(xlim=[480,500])
# ax1R.set(xlim=[480,500])
#
#
# ax2.plot(term/100,e2, color ='darkblue',linewidth=1)
# ax2.set(ylabel=r'$W_{app} \quad [V_0]$', ylim = [0.1,12])
#
# ax2R = ax2.twinx()
# ax2T = ax2.twiny()
# ax2.tick_params(direction='in')
# ax2T.tick_params(direction='in')
# ax2R.tick_params(direction='in')
# ax2R.yaxis.set_major_formatter(plt.NullFormatter())
# ax2T.xaxis.set_major_formatter(plt.NullFormatter())
# ax2T.set(xlim=[480,500])
# ax2R.set(xlim=[480,500])
# ax2R.set(ylabel='(b)',ylim = [0.1,12])
#
#
# ax3.plot(term/100,(e1-e2)/(e1), color ='darkblue',linewidth=1)
# ax3.set(ylabel=r'$ \Delta$')
#
# ax3R = ax3.twinx()
# ax3T = ax3.twiny()
# ax3.tick_params(direction='in')
# ax3T.tick_params(direction='in')
# ax3R.tick_params(direction='in')
# ax3R.yaxis.set_major_formatter(plt.NullFormatter())
# ax3T.xaxis.set_major_formatter(plt.NullFormatter())
# ax3T.set(xlim=[480,500])
# ax3R.set(xlim=[480,500])
# ax3R.set(ylabel='(c)')
#
# ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')
#
#
#
# plt.xlim([480,500])
# plt.subplots_adjust(wspace=0, hspace=0)
# plt.savefig("11_a_Work.pdf", dpi=300, bbox_inches='tight')
# plt.show()

# %%
from matplotlib.gridspec import GridSpec


fig, (ax1, ax3) = plt.subplots(2, sharex=True)

ax1.plot(term/100,e1, color ='darkblue',linewidth=1)

ax1.set(ylabel=r'$Work \quad [V_0]$', ylim = [0.1,13])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.1,13])
ax1T.set(xlim=[480,500])
ax1R.set(xlim=[480,500])


ax1.plot(term/100,e2, color ='orangered',linestyle = 'dashed',linewidth=1)
ax1.text(496,6,r'$W_{app}$',color='orangered')
ax1.text(492,8,r'$W_{ex}$',color='darkblue')


ax3.plot(term/100,(e1-e2)/(e1), color ='darkblue',linewidth=1)
ax3.set(ylabel=r'$ \Delta$',ylim = [-0.22,0.45])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3T.set(xlim=[480,500])
ax3R.set(xlim=[480,500])


ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')

trans = mtransforms.ScaledTranslation(0, 5/72, fig.dpi_scale_trans)
ax1.text(0.94, 0.12, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0.94, 0.12, '(b)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.xlim([480,500])
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_a_Work_b.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
#r e forzante sullo stesso grafico
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.25__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file)

r = data[:,3]-data[:,2]
xcm = (data[:,3]+data[:,2])/2
start = 40000
end = 50000
#calcolo energia immessa
y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))
P = y*(-data[start:end,4]+data[start:end,5])
energy = scipy.integrate.trapz(P, data[start:end,0])
print(energy)
spaces = np.arange(10000)
e1 = np.zeros(10000)

for i in spaces:
    term = int(start + (i+1)*(end-start)/len(spaces))
    e1[i] = scipy.integrate.trapz(P[:int((i+1)*(end-start)/len(spaces))], data[start:term,0])
    
term = start + (spaces+1)*(end-start)/len(spaces)
f = -2*np.pi*np.sin(np.pi*r)*np.cos(np.pi*xcm*2)

fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)

ax1.plot(data[:,0], r , label='$x_2-x_1$', color ='darkblue',linewidth=1)
ax1.plot(data[:,0], R2*np.ones(len(data[:,0])),'orangered', label='$R_2$',linestyle='dashed')
ax1.plot(data[:,0], R1*np.ones(len(data[:,0])), 'forestgreen',label='$R_1$',linestyle='dashed')
ax1.text(407.7, 0.223, '$R_2$',color='orangered')
ax1.text(408.4, 0.155, '$R_1$', color='forestgreen')
ax1.set(ylabel='$r \quad [a]$', ylim = [0.11,0.3])

ax1R = ax1.twinx()
ax1T = ax1.twiny()
ax1.tick_params(direction='in')
ax1T.tick_params(direction='in')
ax1R.tick_params(direction='in')
ax1R.yaxis.set_major_formatter(plt.NullFormatter())
ax1T.xaxis.set_major_formatter(plt.NullFormatter())
ax1R.set(ylim = [0.11,0.3])
ax1T.set(xlim=[400,410])
ax1R.set(xlim=[400,410])


ax2.plot(data[:,0], f , label='$2\sin(\pir) \cos(2\pi x_{cm})$', color ='darkblue',linewidth=1)
ax2.set(ylabel=r'$F_{dri}^{eff} \quad [V_0/a]$',ylim = [-4.9,4.9])

ax2R = ax2.twinx()
ax2T = ax2.twiny()
ax2.tick_params(direction='in')
ax2T.tick_params(direction='in')
ax2R.tick_params(direction='in')
ax2R.yaxis.set_major_formatter(plt.NullFormatter())
ax2T.xaxis.set_major_formatter(plt.NullFormatter())
ax2T.set(xlim=[400,410])
ax2R.set(xlim=[400,410])
ax2R.set(ylim = [-4-9,4.9])



#ax1.annotate("(a)", xy=(0.9, 0.9), xycoords="axes fraction")
#ax2.annotate("(b)", xy=(0.9, 0.9), xycoords="axes fraction")

ax3.plot(term/100,e1, color ='darkblue',linewidth=1)
ax3.set(ylabel=r'$Work \quad [V_0]$', ylim = [0.1,7])

ax3R = ax3.twinx()
ax3T = ax3.twiny()
ax3.tick_params(direction='in')
ax3T.tick_params(direction='in')
ax3R.tick_params(direction='in')
ax3R.yaxis.set_major_formatter(plt.NullFormatter())
ax3T.xaxis.set_major_formatter(plt.NullFormatter())
ax3R.set(ylim = [0.1,7])
ax3T.set(xlim=[400,410])
ax3R.set(xlim=[400,410])

ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')

trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax1.text(0.0, 1.0, '(a)', transform=ax1.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax2.text(0.0, 1.0, '(b)', transform=ax2.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax3.text(0.0, 1.0, '(c)', transform=ax3.transAxes + trans,
            fontsize='medium', verticalalignment='top', fontfamily='serif',
            bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

plt.xlim([400,410])
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("11_a_R_Forzante_2.pdf", dpi=300, bbox_inches='tight')
plt.savefig("11_a_R_Forzante_2.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 58.35204322549273

# %% [markdown]
# '''
# fig = plt.figure(constrained_layout=True)
#
# gs = GridSpec(2, 2, figure=fig)
# ax1 = fig.add_subplot(gs[0, 0])
# ax2 = fig.add_subplot(gs[1, 0],sharex=ax1)
# ax3 = fig.add_subplot(gs[:, 1])
#
# ax1.plot(term/100,e1, color ='darkblue',linewidth=1)
#
# ax1.set(ylabel=r'$W_{exact} \quad [V_0]$', ylim = [0,35])
#
#
# ax1R = ax1.twinx()
# ax1T = ax1.twiny()
# ax1.tick_params(direction='in')
# ax1T.tick_params(direction='in')
# ax1R.tick_params(direction='in')
# ax1R.yaxis.set_major_formatter(plt.NullFormatter())
# ax1T.xaxis.set_major_formatter(plt.NullFormatter())
# ax1R.set(ylabel='(a)',ylim = [0,35])
# ax1T.set(xlim=[450,500])
# ax1R.set(xlim=[450,500])
#
# plt.setp(ax1.get_xticklabels(), visible=False)
#
# ax2.plot(term/100,e2, label='$2\sin(\pir) \cos(2\pi x_{cm})$', color ='darkblue',linewidth=1)
# ax2.set(ylabel=r'$W_{approx} \quad [V_0]$', ylim = [0,29])
#
# ax2R = ax2.twinx()
# ax2T = ax2.twiny()
# ax2.tick_params(direction='in')
# ax2T.tick_params(direction='in')
# ax2R.tick_params(direction='in')
# ax2R.yaxis.set_major_formatter(plt.NullFormatter())
# ax2T.xaxis.set_major_formatter(plt.NullFormatter())
# ax2T.set(xlim=[450,500])
# ax2R.set(xlim=[450,500])
# ax2R.set(ylabel='(b)',ylim = [0,29])
#
# ax2.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')
#
#
# ax3.plot(term/100,(e2-e1)/(e2+e1), color ='darkblue',linewidth=1)
# #ax3.set(ylabel=r'$W_{approx} \quad [V_0]$', ylim = [0,29])
#
# ax3R = ax3.twinx()
# ax3T = ax3.twiny()
# ax3.tick_params(direction='in')
# ax3T.tick_params(direction='in')
# ax3R.tick_params(direction='in')
# ax3R.yaxis.set_major_formatter(plt.NullFormatter())
# ax2T.xaxis.set_major_formatter(plt.NullFormatter())
# ax3T.set(xlim=[450,500])
# ax3R.set(xlim=[450,500])
# #ax3R.set(ylabel='(b)',ylim = [0,29])
#
# ax3.set(xlabel='$t \quad [ a\sqrt{m/V_0} ] $')
#
#
# plt.xlim([450,500])
# plt.subplots_adjust(hspace=0)
# plt.savefig("Work.pdf", dpi=300, bbox_inches='tight')
# plt.show()
# '''

# %%
#cambio spaziatura iniziale

my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.1__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R=0.1')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], (np.sqrt(3)/12)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()


my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.2__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R=0.2')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], 0.25*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/12)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()


my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.135__R2_0.14433756__R3_0.25__c_1.0.dat"
                      ,sep=' ')
data = np.array(my_file) 
plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('R=0.135')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=0.2)
plt.grid()
plt.plot(data[:,0], 0.25*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (np.sqrt(3)/12)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.show()
