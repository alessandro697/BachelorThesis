# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.fft import fft, fftfreq

# %% [markdown]
# Se metto il secondo minimo in un multiplo di a, diventa equivalente a 0. La molecola in un intorno del minimo collassa irreversibilmente, non sono possibili oscillazioni

# %%
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.7__R2_0.7216878365__R3_1.0__c_0.1.dat"
                      ,sep=' ')
data = np.array(my_file) 

R1 = 5*np.sqrt(3)/12
R2 = 1
c = 0.1

plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('F = 7.5, R = 0.7')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
#plt.ylim([1.2,1.3])
plt.xlim([0,100])
plt.show()


y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.6920800924199022
# La frequenza armonica in un intorno di R2 è :  0.17067466214166685
# La barriera di potenziale è :  0.005500849971064825

# %% [markdown]
# Se metto il massimo il un multiplo di a sono possibili 3 comportamenti: collasso a 0, oscillazioni attorno a R2 o equilibrio instabile sul massimo

# %%
my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_0.99__R2_1.0__R3_1.5__c_0.1.dat"
                      ,sep=' ')
data = np.array(my_file) 

R1 = 1
R2 = 1.5
c = 0.1

plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('F = 7.5, R = 0.99')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
#plt.ylim([0.8,1.2])
plt.xlim([0,100])
plt.show()


y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)


my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_1.0__R2_1.0__R3_1.5__c_0.1.dat"
                      ,sep=' ')
data = np.array(my_file) 

plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('F = 7.5, R = R1')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=2)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
plt.ylim([0.8,1.2])
plt.xlim([0,100])
plt.show()


y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)



my_file = pd.read_csv("output___n_2__gam_10.0__U0_1.0__F_7.5__R_1.01__R2_1.0__R3_1.5__c_0.1.dat"
                      ,sep=' ')
data = np.array(my_file) 


plt.xlabel('t')
plt.ylabel('x1-x2')
plt.title('F = 7.5, R = 1.2')
r = -data[:,2]+data[:,3]
plt.plot(data[:,0], r , label='x2-x1',linewidth=1)
plt.plot(data[:,0], R2*np.ones(len(data[:,0])), label='R2',linestyle='dashed')
plt.plot(data[:,0], (R1)*np.ones(len(data[:,0])), label='R1',linestyle='dashed')
plt.legend()
#plt.ylim([0.8,1.2])
plt.xlim([0,100])
plt.show()


y = -2*np.pi*np.sin(np.pi*(-data[start:end,2]+data[start:end,3]))*np.cos(np.pi*(data[start:end,2]+data[start:end,3]))

vcm = np.mean(data[start:end,4]+data[start:end,5])/2
print('La velocità del centro di massa è : ' , vcm)

w = pow(12*c*(pow(R2,4) - pow(R2,2)*pow(R1,2))*2, 1/2)/(2*np.pi)
print('La frequenza armonica in un intorno di R2 è : ' ,w)

delta = (c/2.)*(pow(R2,6)-pow(R1,6)+3*pow(R2,2)*pow(R1,4)-3*pow(R2,4)*pow(R1,2))
print('La barriera di potenziale è : ' ,delta)
# Out:
# La velocità del centro di massa è :  0.6921179284339565
# La frequenza armonica in un intorno di R2 è :  0.41349667156634407
# La barriera di potenziale è :  0.09765625
# La velocità del centro di massa è :  0.6921157625594417
# La frequenza armonica in un intorno di R2 è :  0.41349667156634407
# La barriera di potenziale è :  0.09765625
# La velocità del centro di massa è :  0.6867978997574937
# La frequenza armonica in un intorno di R2 è :  0.41349667156634407
# La barriera di potenziale è :  0.09765625
